# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator

dataset_path = "./rockpaperscissors"

train_datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2
)

train_generator = train_datagen.flow_from_directory(
    dataset_path,
    target_size=(150, 150),
    batch_size=32,
    class_mode='categorical',
    subset='training',
)

validation_generator = train_datagen.flow_from_directory(
    dataset_path,
    target_size=(150, 150),
    batch_size=32,
    class_mode='categorical',
    subset='validation',
)

model = Sequential([
    Conv2D(32, (3,3), activation='relu', input_shape=(150,150,3)),
    MaxPooling2D(2,2),
    Conv2D(64, (3,3), activation='relu'),
    MaxPooling2D(2,2),
    Conv2D(128, (3,3), activation='relu'),
    MaxPooling2D(2,2),
    Flatten(),
    Dense(512, activation='relu'),
    Dense(3, activation='softmax')
])

model.summary()

model.compile(
    loss='categorical_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

history = model.fit(
    train_generator,
    validation_data=validation_generator,
    epochs=10
)

val_loss, val_acc = model.evaluate(validation_generator)
print(f'Validation loss: {val_loss}, Validation accuracy: {val_acc}')

predictions = model.predict(validation_generator)
print(predictions)
# Out:
# Found 1751 images belonging to 3 classes.
# Found 437 images belonging to 3 classes.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 148, 148, 32)      896
#
#  max_pooling2d (MaxPooling2  (None, 74, 74, 32)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 72, 72, 64)        18496
#
#  max_pooling2d_1 (MaxPoolin  (None, 36, 36, 64)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 34, 34, 128)       73856
#
#  max_pooling2d_2 (MaxPoolin  (None, 17, 17, 128)       0
#  g2D)
#
#  flatten (Flatten)           (None, 36992)             0
#
#  dense (Dense)               (None, 512)               18940416
#
#  dense_1 (Dense)             (None, 3)                 1539
#
# =================================================================
# Total params: 19035203 (72.61 MB)
# Trainable params: 19035203 (72.61 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/10
# 55/55 [==============================] - 93s 2s/step - loss: 0.6368 - accuracy: 0.7430 - val_loss: 0.2950 - val_accuracy: 0.8993
# Epoch 2/10
# 55/55 [==============================] - 85s 2s/step - loss: 0.1953 - accuracy: 0.9360 - val_loss: 0.1791 - val_accuracy: 0.9382
# Epoch 3/10
# 55/55 [==============================] - 64s 1s/step - loss: 0.0937 - accuracy: 0.9709 - val_loss: 0.0868 - val_accuracy: 0.9771
# Epoch 4/10
# 55/55 [==============================] - 66s 1s/step - loss: 0.0603 - accuracy: 0.9777 - val_loss: 0.1123 - val_accuracy: 0.9565
# Epoch 5/10
# 55/55 [==============================] - 79s 1s/step - loss: 0.0489 - accuracy: 0.9840 - val_loss: 0.1375 - val_accuracy: 0.9611
# Epoch 6/10
# 55/55 [==============================] - 81s 1s/step - loss: 0.0249 - accuracy: 0.9920 - val_loss: 0.0811 - val_accuracy: 0.9725
# Epoch 7/10
# 55/55 [==============================] - 81s 1s/step - loss: 0.0365 - accuracy: 0.9869 - val_loss: 0.0908 - val_accuracy: 0.9748
# Epoch 8/10
# 55/55 [==============================] - 85s 2s/step - loss: 0.0095 - accuracy: 0.9971 - val_loss: 0.1050 - val_accuracy: 0.9748
# Epoch 9/10
# 55/55 [==============================] - 83s 1s/step - loss: 0.0073 - accuracy: 0.9960 - val_loss: 0.5346 - val_accuracy: 0.8490
# Epoch 10/10
# 55/55 [==============================] - 82s 1s/step - loss: 0.0334 - accuracy: 0.9880 - val_loss: 0.1434 - val_accuracy: 0.9634
# 14/14 [==============================] - 4s 261ms/step - loss: 0.1434 - accuracy: 0.9634
# Validation loss: 0.14335040748119354, Validation accuracy: 0.9633867144584656
# 14/14 [==============================] - 4s 263ms/step
# [[8.8359052e-01 4.0298314e-03 1.1237965e-01]
#  [9.9128211e-01 1.3908510e-09 8.7179011e-03]
#  [1.8342224e-08 9.2486055e-21 1.0000000e+00]
#  ...
#  [1.4649413e-07 5.4420359e-14 9.9999988e-01]
#  [9.9999452e-01 5.2141064e-07 5.0498529e-06]
#  [9.9999988e-01 1.7102151e-11 1.0618017e-07]]
